# %%
import pandas as pd

filename = "housing.csv"
filepath = ""

data = pd.read_csv(filepath+filename)
data.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
# vue les différences (que centième) sur longitude latitude du bien => normaliser mettre sur [0-1] ???
# housing_median_age entier? age median en ans des maisons de la ville
# total_rooms superfice total en inch square
# total_bedrooms superfice total chambre en inch square
# population population de la ville où le bien se situe
# households nb de foyer de la ville où le bien se situe
# median_income revenus médian de la ville où le bien se situe
# median_house_value: valeur médiane des maison dans la villes
# ocean_proximity: str à changer en int
#     INLAND (à l'intérieur des terres), NEAR OCEAN (proche océan), NEAR BAY (proche de la baie), ISLAND (Île)
# manque: le prix de la maison vendu
print("Le tableau de données est de (l/c) : ",data.shape)
# Out:
# Le tableau de données est de (l/c) :  (20640, 10)

# %%
data.tail()
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income  median_house_value  \
# 20635       845.0       330.0         1.5603             78100.0
# 20636       356.0       114.0         2.5568             77100.0
# 20637      1007.0       433.0         1.7000             92300.0
# 20638       741.0       349.0         1.8672             84700.0
# 20639      1387.0       530.0         2.3886             89400.0
#
#       ocean_proximity
# 20635          INLAND
# 20636          INLAND
# 20637          INLAND
# 20638          INLAND
# ...

# %%
print(data.dtypes)
# object string à changer en int
print(data['ocean_proximity'].drop_duplicates())
# 5 types : NEAR BAY, <1H OCEAN, INLAND, NEAR OCEAN, ISLAND
data.plot.scatter("median_income", "median_house_value")
# correlation moyenne avec présence de outlets
# Out:
# longitude             float64
# latitude              float64
# housing_median_age    float64
# total_rooms           float64
# total_bedrooms        float64
# population            float64
# households            float64
# median_income         float64
# median_house_value    float64
# ocean_proximity        object
# dtype: object
# 0         NEAR BAY
# 701      <1H OCEAN
# 954         INLAND
# 1850    NEAR OCEAN
# 8314        ISLAND
# Name: ocean_proximity, dtype: object
# <AxesSubplot:xlabel='median_income', ylabel='median_house_value'>

# %%
data.plot.scatter("longitude", "latitude")
# position sur le territoire
# Out:
# <AxesSubplot:xlabel='longitude', ylabel='latitude'>

# %%
data.plot.scatter("housing_median_age", "median_house_value")
# correlation moyenne avec présence de outlets
data.plot.scatter("total_rooms", "median_house_value")
# correlation moyenne avec présence de outlets
data.plot.scatter("total_bedrooms", "median_house_value")
# correlation moyenne avec présence de outlets
# Out:
# <AxesSubplot:xlabel='total_bedrooms', ylabel='median_house_value'>

# %%
from pandas.plotting import scatter_matrix
import matplotlib.pyplot as plt

fig = plt.figure()
scatter_matrix(data,figsize =(25,25),alpha=0.9,diagonal="kde",marker="o");
# kde = data.hist(figsize=(25,25),bins=50);

# %%
hcorr = data.corr()
hcorr.style.background_gradient()
# Out:
# <style  type="text/css" >
# #T_23520854_d007_11eb_9dbc_5d7b529be736row0_col0,#T_23520854_d007_11eb_9dbc_5d7b529be736row1_col1,#T_23520854_d007_11eb_9dbc_5d7b529be736row2_col2,#T_23520854_d007_11eb_9dbc_5d7b529be736row3_col3,#T_23520854_d007_11eb_9dbc_5d7b529be736row4_col4,#T_23520854_d007_11eb_9dbc_5d7b529be736row5_col5,#T_23520854_d007_11eb_9dbc_5d7b529be736row6_col6,#T_23520854_d007_11eb_9dbc_5d7b529be736row7_col7,#T_23520854_d007_11eb_9dbc_5d7b529be736row8_col8{
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }#T_23520854_d007_11eb_9dbc_5d7b529be736row0_col1,#T_23520854_d007_11eb_9dbc_5d7b529be736row1_col0,#T_23520854_d007_11eb_9dbc_5d7b529be736row1_col8,#T_23520854_d007_11eb_9dbc_5d7b529be736row2_col3,#T_23520854_d007_11eb_9dbc_5d7b529be736row2_col4,#T_23520854_d007_11eb_9dbc_5d7b529be736row2_col5,#T_23520854_d007_11eb_9dbc_5d7b529be736row2_col6,#T_23520854_d007_11eb_9dbc_5d7b529be736row2_col7,#T_23520854_d007_11eb_9dbc_5d7b529be736row3_col2{
# ...

# %%
import seaborn as sns

#heatmap using seaborn
#set the context for plotting 
sns.set(context="paper",font="monospace")
data_corr_matrix = data.corr()
#set the matplotlib figure
fig, axe = plt.subplots(figsize=(12,8))
#Generate color palettes 
cmap = sns.diverging_palette(220,10,center = "light", as_cmap=True)
#draw the heatmap
sns.heatmap(data_corr_matrix,vmax=1,square =True, cmap=cmap,annot=True );

# %%
df = data[['longitude','latitude','ocean_proximity']]
df.drop_duplicates()
# Out:
#        longitude  latitude ocean_proximity
# 0        -122.23     37.88        NEAR BAY
# 1        -122.22     37.86        NEAR BAY
# 2        -122.24     37.85        NEAR BAY
# 3        -122.25     37.85        NEAR BAY
# 6        -122.25     37.84        NEAR BAY
# ...          ...       ...             ...
# 20635    -121.09     39.48          INLAND
# 20636    -121.21     39.49          INLAND
# 20637    -121.22     39.43          INLAND
# 20638    -121.32     39.43          INLAND
# 20639    -121.24     39.37          INLAND
#
# [12590 rows x 3 columns]

# %%
# graph pour le dashboard
data.hist(figsize=(25,25),bins=50);
